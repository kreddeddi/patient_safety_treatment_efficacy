# %%
# Create autoloader_input folder in volume

dbutils.fs.mkdirs("/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/adverse_events")
dbutils.fs.mkdirs("/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/drug_dosing")
dbutils.fs.mkdirs("/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/labs")
dbutils.fs.mkdirs("/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/outcomes")
dbutils.fs.mkdirs("/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/patients")
dbutils.fs.mkdirs("/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/visits")

# %%
# Create checkpoint location in volume
dbutils.fs.mkdirs("/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/checkpoint/autoloader")

# %%
# Copy the files from another volume

dbutils.fs.cp("/Volumes/workspace/clinicaltrial_data/clinicaltrial/patients/", "/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/patients/", recurse=True)
dbutils.fs.cp("/Volumes/workspace/clinicaltrial_data/clinicaltrial/adverse_events/", "/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/adverse_events/", recurse=True)
dbutils.fs.cp("/Volumes/workspace/clinicaltrial_data/clinicaltrial/drug_dosing/", "/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/drug_dosing/", recurse=True)
dbutils.fs.cp("/Volumes/workspace/clinicaltrial_data/clinicaltrial/labs/", "/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/labs/", recurse=True)
dbutils.fs.cp("/Volumes/workspace/clinicaltrial_data/clinicaltrial/outcomes/", "/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/outcomes/", recurse=True)
dbutils.fs.cp("/Volumes/workspace/clinicaltrial_data/clinicaltrial/visits/", "/Volumes/workspace/clinicaltrial_data/clinicaltrial_auto_landing/autoloader_input/visits/", recurse=True)
